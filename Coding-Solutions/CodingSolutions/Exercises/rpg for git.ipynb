# %%
from string import ascii_uppercase
from string import digits
from string import punctuation
from random import shuffle
from string import ascii_lowercase
import random
def password_generator():
    punc_list = ['!','#', '$', '%', '&', '*', '+', ',', '-', '.','?', '@', '^', '_',]
    print("                               WELCOME TO RPG !!\n")
    print("   \n\n")
    print("lowercase : {} \nuppercase: {} \ndigits : {} \npunctuation: {}".format(ascii_lowercase,ascii_uppercase,digits,punc_list))
def punc_list_option():
    punc_list = ['!','#', '$', '%', '&', '*', '+', ',', '-', '.','?', '@', '^', '_',]
    take_input= int(input("How many punctuation chars do you  want? \n-->"))
    popped_list = []
        
    for picks in range(take_input):
        popped = punc_list.pop(random.randint(0,len(punc_list)))
        popped_list.append(popped)
    print("{} chars left".format(total_length_input-take_input))
        
    return popped_list
    
def uppercase_option():
    uppers_list = list(ascii_uppercase)
    take_input= int(input("How many uppercase chars do you  want? \n-->"))
    popped_list = []
        
    for picks in range(take_input):
        popped = uppers_list.pop(random.randint(0,len(uppers_list)))
        popped_list.append(popped)
    print("{} chars left".format(total_length_input-take_input))
        
    return popped_list
    
def total_length():
    total_length_input = int(input("How many chars do you want in your password? \n -->"))
    return total_length_input
def lowercase_option():
    lowers_list = list(ascii_lowercase)
    take_input= int(input("How many lowercase chars do you  want? \n-->"))
    popped_list = []
        
        
    for picks in range(take_input):
        popped = lowers_list.pop(random.randint(0,len(lowers_list)-1))
        popped_list.append(popped)
    print("{} chars left".format(total_length_input-take_input))
        
    return popped_list
    
def nums_option():
    nums_list = list(digits)
    take_input= int(input("How many digits do you  want? \n-->"))
    popped_list = []
        
    for picks in range(take_input):
        popped = nums_list.pop(random.randint(0,len(nums_list)-1))
        popped_list.append(popped)
    print("{} chars left".format(total_length_input-take_input))
    return popped_list
    
def mixed_list_with_chosen_types():
    
    
    essentials = ["d","u","l","p"]
    m_list = []

    char_type_input= input("Choose char types in password: \n U ==> Uppercase Letters \n L ==>Lowercase Letters \n D ==> Digits \n P ==> Punctuation\n ")
    for letter in char_type_input:
        if letter.lower() == "u":
            up=uppercase_option()
            m_list.extend(up)
        elif letter.lower() == "l":
            lo = lowercase_option()
            m_list.extend(lo)
        elif letter.lower() == "d":
            di = nums_option()
            m_list.extend(di)
        elif letter.lower() == "p":
            pu = punc_list_option()
            m_list.extend(pu)
        else:
            pass
    random.shuffle(m_list)
    return "".join(m_list)    
    
while True:

    password_generator()
    print("\n\n")
    total_length_input=total_length()
    len_mixed = mixed_list_with_chosen_types()
    if total_length_input > len(len_mixed):
        print("Chars are less than you want")
        mixed_list_with_chosen_types()
        continue
    elif total_length_input < len(len_mixed):
        print("Chars are more than you want")
        mixed_list_with_chosen_types()
        continue
    elif total_length_input == len(len_mixed):
        print(len_mixed)
        break
    else:
        continue
